# %%
import pickle
import numpy as np

# %%
pipe = pickle.load(open('pipe.pkl', 'rb'))

# %%
import pandas as pd

sample = pd.DataFrame([{
    'Pclass': 3,
    'Sex': 'male',
    'Age': 22,
    'SibSp': 1,
    'Parch': 0,
    'Fare': 7.25,
    'Embarked': 'S'
}])

pipe.predict(sample)
# Out:
# array([0])
